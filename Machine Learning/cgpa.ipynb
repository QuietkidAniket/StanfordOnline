# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""
Branch : ECM + ECE + BVD
Room no. : 702
1st semester 2023-24
Batch of 27
"""
data = [
    ['m', 'n', 6.1], 
    ['m', 'n', 7.9],
    ['m', 's', 8.6], 
    ['f', 's', 9.4],
    ['m', 'n', 9.2],
    ['m', 'n', 8.9],
    ['m', 'n', 9.4],
    ['f', 'n', 9.08],
    ['f', 's', 7.8],
    ['m', 'n', 8.2],
    ['m', 'n', 8.3],
    ['m', 'n', 8.4],
    ['m', 'n', 6.0],
    ['m', 's', 7.4],
    ['m', 's', 9.6],
    ['f', 'n', 9.3],
    ['m', 'n', 9.18],
    ['m', 'n', 9.7],
    ['f', 's', 8.6],
    ['m', 'n', 6.1],
    ['f', 'n', 8.2],
    ['m', 'n', 7.8],
    ['m', 'n', 8.2],
    ['m', 's', 8.92],
    ['m', 'n', 9.1],
    ['m', 'n', 9.5],
    ['m', 's', 9.8],
    ['m', 's', 9.7],
    ['m', 's', 8.1],
    ['f', 'n', 8.3],
    ['m', 'n', 8.3],
    ['f', 'n', 8.3],
    ['m', 'n', 8.3],
    ['m', 'n', 8.3]
]

# %%
dataframe = pd.DataFrame(data, columns = ['sex', 'origin', 'cgpa'])
dataframe
# Out:
#    sex origin  cgpa
# 0    m      n  6.10
# 1    m      n  7.90
# 2    m      s  8.60
# 3    f      s  9.40
# 4    m      n  9.20
# 5    m      n  8.90
# 6    m      n  9.40
# 7    f      n  9.08
# 8    f      s  7.80
# 9    m      n  8.20
# 10   m      n  8.30
# 11   m      n  8.40
# 12   m      n  6.00
# 13   m      s  7.40
# 14   m      s  9.60
# 15   f      n  9.30
# 16   m      n  9.18
# 17   m      n  9.70
# 18   f      s  8.60
# 19   m      n  6.10
# 20   f      n  8.20
# 21   m      n  7.80
# 22   m      n  8.20
# 23   m      s  8.92
# 24   m      n  9.10
# 25   m      n  9.50
# 26   m      s  9.80
# 27   m      s  9.70
# 28   m      s  8.10
# 29   f      n  8.30
# 30   m      n  8.30
# 31   f      n  8.30
# 32   m      n  8.30
# 33   m      n  8.30

# %%
dataframe['cgpa'].hist()
plt.xlabel('cgpa')
plt.title('class of 2027 1st sem AB1 702 cgpa distribution')
# Out:
# Text(0.5, 1.0, 'class of 2027 1st sem AB1 702 cgpa distribution')

# %%
cgpasorted = dataframe['cgpa'].sort_values()
cgpasorted.value_counts()
# Out:
# cgpa
# 8.30    6
# 8.20    3
# 9.70    2
# 7.80    2
# 9.40    2
# 8.60    2
# 6.10    2
# 6.00    1
# 9.18    1
# 9.60    1
# 9.50    1
# 9.30    1
# 9.20    1
# 8.92    1
# 9.10    1
# 9.08    1
# 8.90    1
# 8.40    1
# 8.10    1
# 7.90    1
# 7.40    1
# 9.80    1
# Name: count, dtype: int64

# %%
sns.scatterplot(x=dataframe['origin'], y = dataframe['cgpa'], hue = dataframe['sex'])
# Out:
# <Axes: xlabel='origin', ylabel='cgpa'>
